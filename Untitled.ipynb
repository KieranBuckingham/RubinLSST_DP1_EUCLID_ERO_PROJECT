# %%
import shutil
shutil.make_archive("KB_462", "zip", root_dir=".", base_dir="KB_462")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import shutil
# ----> 2 shutil.make_archive("KB_462", "zip", root_dir=".", base_dir="KB_462")
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0-exact/lib/python3.12/shutil.py:1161, in make_archive(base_name, format, root_dir, base_dir, verbose, dry_run, owner, group, logger)
#    1158             os.chdir(root_dir)
#    1160 try:
# -> 1161     filename = func(base_name, base_dir, **kwargs)
#    1162 finally:
#    1163     if save_cwd is not None:
#
# File /opt/lsst/software/stack/conda/envs/lsst-scipipe-10.1.0-exact/lib/python3.12/shutil.py:1021, in _make_zipfile(base_name, base_dir, verbose, dry_run, logger, owner, group, root_dir)
#    1019 base_dir = os.path.normpath(base_dir)
#    1020 if arcname != os.curdir:
# -> 1021     zf.write(base_dir, arcname)
# ...
